# %%
import pulp

# %%
lp = pulp.LpProblem('lp', sense=1)

# %%
lp
# Out:
# lp:
# MINIMIZE
# None
# VARIABLES

# %%
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)

# %%
def solver(objective, constrainsts):
    
    variable_count = len(objective[0])
    
    lp_sense = -1 if objective[1][0] == "max" else 1
    lp = pulp.LpProblem('lp', sense=lp_sense)
    
    variables = list()
    
    for i in range(variable_count):
        variables.append(pulp.LpVariable(name="x" + str(i), lowBound=0))
    
    lp += objective_function(objective[0], variables)
    
    constraint_function(constrainsts[0], variables)
    print(lp)

# %%
def objective_function(objective, variables):
    
    objective_func = ""
    
    for obj, var in zip(objective, variables):
        objective_func += obj * var
        
    return objective_func

# %%
def constraint_function(constraint, variables):
    
    variables.extend([1, 1])
    
    constraint_func = ""
    
    for cons, var in zip(constraint, variables):
        constraint_func += cons * var
        
    return constraint_func

# %%
solver([[4.0, 3.0], ['max']],
        [[1.0, 2.0, '<=', 25.0], [2.0, 4.0, '<=', 8.0], [-2.0, 1.0, '<=', -5.0]])
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-112-3c73c56d0187> in <module>
#       1 solver([[4.0, 3.0], ['max']],
# ----> 2         [[1.0, 2.0, '<=', 25.0], [2.0, 4.0, '<=', 8.0], [-2.0, 1.0, '<=', -5.0]])
#
# <ipython-input-107-93fb0fb1a202> in solver(objective, constrainsts)
#      13     lp += objective_function(objective[0], variables)
#      14
# ---> 15     lp += constraint_function(constrainsts[0], variables)
#      16     print(lp)
#      17
#
# <ipython-input-111-eb6c74686ede> in constraint_function(constraint, variables)
#       6
#       7     for cons, var in zip(constraint, variables):
# ----> 8         constraint_func += cons * var
#       9
#      10     return constraint_func
#
# ~/opt/anaconda3/envs/indr262/lib/python3.6/site-packages/pulp/pulp.py in __iadd__(self, other)
#     783
#     784     def __iadd__(self, other):
# --> 785         return self.addInPlace(other)
#     786
#     787     def __sub__(self, other):
#
# ~/opt/anaconda3/envs/indr262/lib/python3.6/site-packages/pulp/pulp.py in addInPlace(self, other)
#     741               or isinstance(other, Iterable)):
#     742            for e in other:
# --> 743                 self.addInPlace(e)
#     744         else:
#     745             self.constant += other
#
# ... last 1 frames repeated, from the frame below ...
#
# ~/opt/anaconda3/envs/indr262/lib/python3.6/site-packages/pulp/pulp.py in addInPlace(self, other)
#     741               or isinstance(other, Iterable)):
#     742            for e in other:
# --> 743                 self.addInPlace(e)
#     744         else:
#     745             self.constant += other
#
# RecursionError: maximum recursion depth exceeded in comparison
